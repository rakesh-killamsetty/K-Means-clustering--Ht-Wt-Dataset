# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_excel("/content/ht_wt.xlsx")
data
# Out:
#     srno  height  weight
# 0      1     185      72
# 1      2     170      56
# 2      3     168      60
# 3      4     179      68
# 4      5     182      72
# 5      6     188      77
# 6      7     180      71
# 7      8     180      70
# 8      9     183      84
# 9     10     180      84
# 10    11     168      90

# %%
x=data.drop('srno',axis=1)

# %%
from sklearn.cluster import KMeans
kmeans=KMeans(n_clusters=3)
train=kmeans.fit_predict(x)
train
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([1, 2, 2, 1, 1, 1, 1, 1, 0, 0, 0], dtype=int32)

# %%
ypred=kmeans.predict(x)
ypred
# Out:
# array([1, 2, 2, 1, 1, 1, 1, 1, 0, 0, 0], dtype=int32)

# %% [markdown]
# 1.   split it as 0 and 1
# 2.   Newly entered data(168,60) compare 0(185,72) and 1st(170,56) category elements
# 3.   compare with 0th category
# 4.   (185-168)  gives 17,(72-60) gives 12
# 5.   Square the 17 and square the 12
# 6.   we will get 289 and 144
# 7.   add 289 and 144,we get 433
# 8.   Take the square root of 433, you will get 20
#
#
# 9.   Repeat the steps from 3-8 wth 1st category(170,56)
# 10.   thereby you can get 4
#
#
# 11.   Compare the two categories answers 20 and 4.4 is smaller
# 12.   4 belongs to 1st category , so new data (168,60) is 1st category.
# 13. Now , you have two 2st category elements(170,56),(168,60) so take the median for these two, it results (168,60)
# now entered the data for 1st category using these elements (169,58).

# %%
data['category']=ypred
data
# Out:
#     srno  height  weight  category
# 0      1     185      72         1
# 1      2     170      56         2
# 2      3     168      60         2
# 3      4     179      68         1
# 4      5     182      72         1
# 5      6     188      77         1
# 6      7     180      71         1
# 7      8     180      70         1
# 8      9     183      84         0
# 9     10     180      84         0
# 10    11     168      90         0
